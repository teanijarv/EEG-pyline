# %% [markdown]
# ### Hierarchical Linear Regression
# Adapted from Github repository by R. Boyle - https://github.com/rorytboyle/hierarchical_regression

# %%
# Import packages
import pandas as pd
import statsmodels.api as sm
import scipy.stats
import numpy as np

# Set default directory
os.chdir('/Users/tanijarv/Documents/GitHub/EEG-pyline')

# Import functions
from stats.hierarchical_regression import *

# %% [markdown]
# Define these variables!

# %% [markdown]
# Run this to set the folders for data.

# %%
savefinal_folder = 'Results/LABS-LEISURE/'

exp_folder = ['LABS-LEISURE/Eyes Closed/LEISURE', 'LABS-LEISURE/Eyes Closed/LABS']
exp_condition = ['LEISURE', 'LABS']

df_wo_bads = pd.read_excel('{}/specparam_{}-linear.xlsx'.format(savefinal_folder, str(exp_condition)), index_col=0)

# %%
df_wo_bads
# Out:
#                 Exponent    Offset  Theta absolute power  \
# HBA_0001_EC_T1  0.796945  0.562065              0.892525
# HBA_0003_EC_T1  0.927303  0.570202              1.023936
# HBA_0004_EC_T1  1.176063  0.575699              1.557742
# HBA_0005_EC_T1  1.128006  0.216055              0.993994
# HBA_0006_EC_T1  0.719606 -0.039952              0.818441
# ...                  ...       ...                   ...
# LAB_9754_02_EC  1.245624  1.437844              1.758201
# LAB_9805_06_EC  1.414764  1.027088              1.844568
# LAB_9829_02_EC  1.488261  1.503889              1.168007
# LAB_9941_04_EC  1.417318  1.286104              1.159446
# LAB_9966_02_EC  1.462735  1.809587              1.640791
#
#                 Theta relative power       R_2     Error          Region  \
# HBA_0001_EC_T1              0.518236  0.945886  0.054064    Left frontal
# HBA_0003_EC_T1              0.727538  0.977220  0.039497    Left frontal
# ...

# %%
X = [df_wo_bads['Exponent'],
     df_wo_bads[['Exponent', 'Offset']],
     df_wo_bads[['Exponent', 'Offset', 'Error']]]
names = [['Exponent'],
         ['Exponent', 'Offset'], 
         ['Exponent', 'Offset', 'Error']]
y = df_wo_bads['R_2']

results, models = hierarchical_regression(y, X, names, 
                                          'Results/regression_results')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 9
#       4 names = [['Exponent'],
#       5          ['Exponent', 'Offset'],
#       6          ['Exponent', 'Offset', 'Error']]
#       7 y = df_wo_bads['R_2']
# ----> 9 results, models = hierarchical_regression(y, X, names,
#      10                                           'Results/regression_results')
#
# File ~/Documents/GitHub/EEG-pyline/stats/hierarchical_regression.py:165, in hierarchical_regression(y, X, names, saveFolder)
#     162 currentStepModel.save(modelSave) # THIS LINE HASNT BEEN TESTED
#     164 # run regression diagnostics
# --> 165 assumptionsToCheck = regression_diagnostics(
#     166         currentStepModel, currentStepResults, y, currentX, saveto)
#     167 currentStepResults.append(assumptionsToCheck)
#     169 results.append(currentStepResults)
#
# ...

# %%
# read in data
nba = pd.read_csv('{}/NBA_train.csv'.format(savefinal_folder))

# prep data
nba['interaction'] = nba['PTS'] * nba['ORB']
X = [nba['PTS'], nba[['PTS', 'ORB']], nba[['PTS', 'ORB', 'interaction']]]
y = nba['W']
names = [['points'], ['points', 'offensive_rebounds'], 
         ['points', 'offensive_rebounds', 'interaction']]

results, models = hierarchical_regression(y, X, names, 
                                          'Results/regression_results')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 11
#       7 y = nba['W']
#       8 names = [['points'], ['points', 'offensive_rebounds'],
#       9          ['points', 'offensive_rebounds', 'interaction']]
# ---> 11 results, models = hierarchical_regression(y, X, names,
#      12                                           'Results/regression_results')
#
# File ~/Documents/GitHub/EEG-pyline/stats/hierarchical_regression.py:165, in hierarchical_regression(y, X, names, saveFolder)
#     162 currentStepModel.save(modelSave) # THIS LINE HASNT BEEN TESTED
#     164 # run regression diagnostics
# --> 165 assumptionsToCheck = regression_diagnostics(
#     166         currentStepModel, currentStepResults, y, currentX, saveto)
#     167 currentStepResults.append(assumptionsToCheck)
#     169 results.append(currentStepResults)
#
# ...

# %%
import pingouin as pg
pg.read_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
