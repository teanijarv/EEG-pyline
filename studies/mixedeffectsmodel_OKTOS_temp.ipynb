# %%
# Import packages
import mne, os
import pandas as pd
import statsmodels.formula.api as smf

# Set the default directory (REMOVE THIS AS THIS IS RELEVANT ONLY TO MY PROJECT DIRECTORY)
os.chdir('/Users/tanijarv/Documents/GitHub/EEG-pyline')

# %%
# Folder where to save the results and plots
results_folder = 'Results/'

# Sub-folder for the experiment (i.e. timepoint or group) and its acronym
exp_folder = 'OKTOS'

# Channels and ERPs of interest
channels = ['Cz', 'Pz']
erp_measures = ['P3_latency', 'P3_amplitude']

# %%
# Read the data
df = pd.read_excel('{}/{}/OKTOS_AO_df.xlsx'.format(results_folder, exp_folder))

# %%
# Go through all channels of interest
for ch in channels:
    print('\nChannel: {}'.format(ch))
    df_ch = df[df['Channel']==ch]

    # Make the Timepoint a categorical column
    df_ch_cat = df_ch.copy()
    df_ch_cat['Timepoint'] = pd.Categorical(df_ch_cat['Timepoint'], categories=['PRE', 'POST', 'FUP'], ordered=True)

    # Run Mixed Linear Model for all ERP measures of interest as dependent variable
    for erp in erp_measures:
        # Define the model as fixed effects being Timepoint and Responder and random effect being group (i.e., Subject)
        model = smf.mixedlm('{} ~ Timepoint * Responder'.format(erp), df_ch_cat, groups=df_ch_cat['Subject'])
        result = model.fit()
        print(result.summary())
# Out:
# Channel: Cz
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                  MixedLM       Dependent Variable:       P3_latency
# No. Observations:       72            Method:                   REML
# No. Groups:             24            Scale:                    778.0992
# Min. group size:        3             Log-Likelihood:           -339.3614
# Max. group size:        3             Converged:                Yes
# Mean group size:        3.0
# --------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z|  [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                    346.802   15.596 22.237 0.000 316.234 377.369
# Timepoint[T.POST]             16.235   13.947  1.164 0.244 -11.101  43.571
# Timepoint[T.FUP]              -2.930   13.947 -0.210 0.834 -30.266  24.406
# Responder                    -13.855   19.101 -0.725 0.468 -51.293  23.583
# Timepoint[T.POST]:Responder  -10.681   17.082 -0.625 0.532 -44.161  22.799
# Timepoint[T.FUP]:Responder     4.333   17.082  0.254 0.800 -29.146  37.813
# Group Var                   1167.793   18.893
# ==========================================================================
#
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                MixedLM     Dependent Variable:     P3_amplitude
# No. Observations:     72          Method:                 REML
# No. Groups:           24          Scale:                  1.8433
# Min. group size:      3           Log-Likelihood:         -136.2327
# Max. group size:      3           Converged:              Yes
# Mean group size:      3.0
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    1.954    0.676  2.889 0.004  0.628  3.279
# Timepoint[T.POST]            0.119    0.679  0.175 0.861 -1.212  1.449
# Timepoint[T.FUP]             0.280    0.679  0.412 0.680 -1.051  1.610
# Responder                    0.570    0.828  0.689 0.491 -1.053  2.194
# Timepoint[T.POST]:Responder -0.900    0.831 -1.083 0.279 -2.530  0.729
# Timepoint[T.FUP]:Responder   0.156    0.831  0.188 0.851 -1.473  1.786
# Group Var                    1.815    0.661
# ======================================================================
#
#
# Channel: Pz
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      P3_latency
# No. Observations:        72           Method:                  REML
# No. Groups:              24           Scale:                   645.3911
# Min. group size:         3            Log-Likelihood:          -330.0409
# Max. group size:         3            Converged:               Yes
# Mean group size:         3.0
# -------------------------------------------------------------------------
#                              Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# -------------------------------------------------------------------------
# Intercept                   374.146   12.842 29.135 0.000 348.976 399.315
# Timepoint[T.POST]            -8.301   12.702 -0.653 0.513 -33.197  16.595
# Timepoint[T.FUP]             -7.568   12.702 -0.596 0.551 -32.464  17.328
# Responder                    -8.057   15.728 -0.512 0.608 -38.883  22.769
# Timepoint[T.POST]:Responder  -7.629   15.557 -0.490 0.624 -38.121  22.862
# Timepoint[T.FUP]:Responder    7.263   15.557  0.467 0.641 -23.228  37.754
# Group Var                   673.891   12.923
# =========================================================================
#
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                MixedLM     Dependent Variable:     P3_amplitude
# No. Observations:     72          Method:                 REML
# No. Groups:           24          Scale:                  1.1471
# Min. group size:      3           Log-Likelihood:         -127.9734
# Max. group size:      3           Converged:              Yes
# Mean group size:      3.0
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    2.140    0.682  3.136 0.002  0.803  3.478
# Timepoint[T.POST]            0.596    0.536  1.113 0.266 -0.454  1.645
# Timepoint[T.FUP]             0.466    0.536  0.871 0.384 -0.583  1.516
# Responder                    1.350    0.836  1.616 0.106 -0.288  2.989
# Timepoint[T.POST]:Responder -1.413    0.656 -2.154 0.031 -2.698 -0.127
# Timepoint[T.FUP]:Responder  -1.181    0.656 -1.801 0.072 -2.467  0.104
# Group Var                    2.579    1.021
# ======================================================================
